# %% [markdown]
# # Spark MLlib

# %% [markdown]
# - MLlib 是基于 spark-dataframe 构建的

# %%
import findspark
findspark.init("/Users/xinby/Library/Spark")


from pyspark.sql import SparkSession
spark = SparkSession.builder.\
    master("local[*]").\
    config("spark.executor.memory", "4g").\
    config("spark.driver.memory", "4g").\
    config("spark.ui.showConsoleProgress", "false").\
    appName("MLlib").\
    getOrCreate()
sc = spark.sparkContext
# sc.setLogLevel("ERROR")
print(spark)
print(sc)
# Out:
# <pyspark.sql.session.SparkSession object at 0x7f7c10f7cc10>
# <SparkContext master=local[*] appName=MLlib>

# %% [markdown]
# ### 数据读取

# %% [markdown]
# 我们依然使用弹幕数据：

# %%
# cids = [144541892, 144541943, 160377038, 148952771, 150894103, 153392221, 156629080, 159982308, 162395026]
cids = [144541892, 144541943, 160377038, 148952771, 150894103]
jsons = [f"data/lec14-danmu-{cid}.json" for cid in cids]
jsons
# Out:
# ['data/lec14-danmu-144541892.json',
#  'data/lec14-danmu-144541943.json',
#  'data/lec14-danmu-160377038.json',
#  'data/lec14-danmu-148952771.json',
#  'data/lec14-danmu-150894103.json']

# %%
df = spark.read.json(jsons, multiLine=True)
df.count()
# Out:
# 11574000

# %% [markdown]
# 出于演示目的，我们随机抽取一小部分数据并缓存：

# %%
df_small = df.sample(withReplacement=False, fraction=0.001, seed=123)
df_small.cache()
df_small.show(n=15)
df_small.count()
# Out:
# +---------+----------------------------------+----------+-----------------+----+----------+
# |      cid|                           content|      date|               id|mode| post_time|
# +---------+----------------------------------+----------+-----------------+----+----------+
# |160377038|                            脱水！|2020-01-28|29497785794953219|   1|1580223858|
# |160377038|                        技术公有化|2020-01-28|29497829588205573|   1|1580217034|
# |160377038|                              脱水|2020-01-28|29497829597642757|   1|1580217024|
# |160377038|                              浸泡|2020-01-28|29497833691807747|   1|1580216633|
# |160377038|                          空位是？|2020-01-28|29497835948343299|   1|1580216368|
# |160377038|                    你也会空中劈叉|2020-01-28|29497842766184453|   5|1580215732|
# |160377038|                              脱水|2020-01-29|29497694497013763|   1|1580310440|
# |160377038|                    让  我  先  跑|2020-01-29|29497730623078403|   5|1580281402|
# |160377038|                        组织生活会|2020-01-29|29497759658672133|   1|1580255800|
# |160377038|                          当场揭穿|2020-01-30|29497673583165443|   5|1580376327|
# |160377038|                                演|2020-01-30|29497677668941829|   1|1580366046|
# |160377038|                       对 号 入 座|2020-01-30|29497677688864773|   1|1580365701|
# |160377038|                          狼人自刀|2020-01-30|29497732341170179|   1|1580280897|
# |160377038|倍啥速，我都是一段段的反复看好几遍|2020-01-31|29497641280733187|   5|1580478569|
# |160377038|                              浸泡|2020-01-31|29497650110267395|   1|1580445659|
# +---------+----------------------------------+----------+-----------------+----+----------+
# only showing top 15 rows
# 11500

# %% [markdown]
# ### 数据转换与特征提取

# %% [markdown]
# 除了 PySpark 自带的变换操作，我们还可以直接编写 Python 函数（基于 Pandas）对数据进行变换，如对弹幕进行分词。

# %%
import jieba
from pyspark.sql.types import StringType
from pyspark.sql.functions import udf

def seg_words(danmu):
    # 弹幕通常包含大量空格以醒目，但破坏语义，先移除
    danmu = danmu.replace(" ", "")
    # 生成一个含有切分后词语的迭代器
    cut = jieba.lcut(danmu, cut_all=False)
    # 去掉多余的空格
    cut = filter(lambda x: x != " ", cut)
    # 再用空格将词语合并
    return " ".join(cut)

seg_words_udf = udf(seg_words, StringType())

# %%
df_seg = df_small.withColumn("seg", seg_words_udf(df_small.content))
df_seg.cache()
df_seg.show(n=10)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /var/folders/wk/fm3ylspx3ml0t03x529wz0n80000gn/T/jieba.cache
# Loading model cost 0.878 seconds.
# Prefix dict has been built successfully.
# +---------+--------------+----------+-----------------+----+----------+------------------+
# |      cid|       content|      date|               id|mode| post_time|               seg|
# +---------+--------------+----------+-----------------+----+----------+------------------+
# |160377038|        脱水！|2020-01-28|29497785794953219|   1|1580223858|           脱水 ！|
# |160377038|    技术公有化|2020-01-28|29497829588205573|   1|1580217034|       技术 公有化|
# |160377038|          脱水|2020-01-28|29497829597642757|   1|1580217024|              脱水|
# |160377038|          浸泡|2020-01-28|29497833691807747|   1|1580216633|              浸泡|
# |160377038|      空位是？|2020-01-28|29497835948343299|   1|1580216368|        空位 是 ？|
# |160377038|你也会空中劈叉|2020-01-28|29497842766184453|   5|1580215732|你 也 会 空中 劈叉|
# |160377038|          脱水|2020-01-29|29497694497013763|   1|1580310440|              脱水|
# |160377038|让  我  先  跑|2020-01-29|29497730623078403|   5|1580281402|       让 我 先 跑|
# |160377038|    组织生活会|2020-01-29|29497759658672133|   1|1580255800|       组织生活 会|
# |160377038|      当场揭穿|2020-01-30|29497673583165443|   5|1580376327|         当场 揭穿|
# +---------+--------------+----------+-----------------+----+----------+------------------+
# only showing top 10 rows

# %% [markdown]
# 接下来使用 MLlib 中的 `Tokenizer` 转换器来将词语转为列表：

# %%
from pyspark.ml.feature import Tokenizer, StopWordsRemover

tok = Tokenizer(inputCol="seg", outputCol="words")
df_tok = tok.transform(df_seg)
df_tok.select("seg", "words").show(n=10)
# Out:
# +------------------+------------------------+
# |               seg|                   words|
# +------------------+------------------------+
# |           脱水 ！|              [脱水, ！]|
# |       技术 公有化|          [技术, 公有化]|
# |              脱水|                  [脱水]|
# |              浸泡|                  [浸泡]|
# |        空位 是 ？|          [空位, 是, ？]|
# |你 也 会 空中 劈叉|[你, 也, 会, 空中, 劈叉]|
# |              脱水|                  [脱水]|
# |       让 我 先 跑|        [让, 我, 先, 跑]|
# |       组织生活 会|          [组织生活, 会]|
# |         当场 揭穿|            [当场, 揭穿]|
# +------------------+------------------------+
# only showing top 10 rows

# %% [markdown]
# 移除停用词：

# %%
stop_words = ["的", "了", "是", "，", "。", "？", "！", "：", "（", "）", "“", "”", ".", "…", "."]
rmstop = StopWordsRemover(inputCol="words", outputCol="filtered", stopWords=stop_words)
df_rmstop = rmstop.transform(df_tok)
df_rmstop.select("words", "filtered").show(n=10)
# Out:
# +------------------------+------------------------+
# |                   words|                filtered|
# +------------------------+------------------------+
# |              [脱水, ！]|                  [脱水]|
# |          [技术, 公有化]|          [技术, 公有化]|
# |                  [脱水]|                  [脱水]|
# |                  [浸泡]|                  [浸泡]|
# |          [空位, 是, ？]|                  [空位]|
# |[你, 也, 会, 空中, 劈叉]|[你, 也, 会, 空中, 劈叉]|
# |                  [脱水]|                  [脱水]|
# |        [让, 我, 先, 跑]|        [让, 我, 先, 跑]|
# |          [组织生活, 会]|          [组织生活, 会]|
# |            [当场, 揭穿]|            [当场, 揭穿]|
# +------------------------+------------------------+
# only showing top 10 rows

# %% [markdown]
# 进而使用 `CountVectorizer` 来统计词频：

# %%
from pyspark.ml.feature import CountVectorizer, IDF

# minDF 表示进入字典的词最少需要在多少句子（弹幕）中出现
# vocabSize 表示取词频前几位的词语作为字典
counter = CountVectorizer(inputCol="filtered", outputCol="features",
                          minDF=10, vocabSize=500)

counter_model = counter.fit(df_rmstop)
print(counter_model.vocabulary)
# Out:
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/wk/fm3ylspx3ml0t03x529wz0n80000gn/T/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/wk/fm3ylspx3ml0t03x529wz0n80000gn/T/jieba.cache
# Loading model from cache /var/folders/wk/fm3ylspx3ml0t03x529wz0n80000gn/T/jieba.cache
# Loading model cost 1.025 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.024 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.024 seconds.
# Prefix dict has been built successfully.
# ['我', '北海', '你', '章', '智子', '啊', '浸泡', '要', '好', '想', '这', '在', '老', '人', '多', '都', '跑', '剧毒', '不', '吗', '有', '水是', '就', '者', '也', '他', '敬礼', '*', '不是', '对', '面壁', '前进', '大', '人类', '》', '《', '来', '脱水', '罗辑', '地球', '钢印', '说', '航天', ':', '时代', '变', '计划', '四', '三体', '兄弟', '刘', '很', '就是', '思想', '我们', '—', '这个', '模范', '吧', '夫妻', '哈哈哈', '呢', '什么', '一个', '先', '自己', '开始', '还', '这是', '一样', '号', '看', '老子', '谢谢', '主', '!', '那', '影帝', '~', 'eto', '个', '给', '和', 'tm', '未来', '丁仪', '真', '～', '场面', '子', '被', '死', '把', '未', '能', '可以', '陨石', '援', '增', '打', '维德', '?', '已经', '破壁', '好评', '知道', '上', '自然选择', '(', '大海', '去', '哈哈', '怎么', ')', '逃亡', '得', '前方', '大史', '流浪', '先跑', '名', '他们', '高能', '同志', '啥', '路', '技术', '不要', '又', '快', '用', '太空', '致敬', '三', '太', '@', '美国', '牛', '危', '演', '现在', 'doge', '谁', '笑', '爆炸', '逼', '耳机', '=', '让', '一部分', '不在乎', '子弹', '真的', '●', '哈哈哈哈', '中国', '最', '这么', '队友', '更', '懂', '应该', 'mc', '将', '会', '呀', '·', '秦始皇', '那个', '中', '文明', '征途', '这里', '孩子', '恩斯', '翻译', '为什么', '吴岳', '还有', '一', '不会', '刘培强', '到', '派', '骂', '主义', '再', '么', '希', '两个', '起', '水', '常伟思', '其实', '按', '可', '才', '广袤', '所以', '不过', '日本', '星辰', '正常', '逻辑', '敌人', '惠子', '经费', '做', '程心', '质子', '加密', '着', '我要', '从', '因为', '可能', '史学', '方', '】', '里', '成功', '众所周知', '叫', '高', '狂徒', '量产', '表示', '野生', ',', '那边', '爱', '末', '【', '中文', '法外', '专业', '狼', '杀', '音效', '有毒', '细节', '长征', '希望', '学生', '两千', '云', '宇宙', '水滴', '确实', '您', '话', '唐号', '正在', '金鱼', '多响', '小', '啦', '人类文明', '海', '直接', '害怕', '像', '影人', '神', 'rec', '直呼', '通话', '完', '圆', '内行', '语言', '枪法', '为', '尊师重道', '好像', '过', '信念', '哈', '们', '鬼', '滑稽', '与', '局座', '只是', '冬眠', '但', '韦德', '天明', '之前', 'nb', '内', '泪目', '这样', '送', '需要', '狗', '请', '森林', '最后', '看到', '意思', '目标', '星', '卖', '眼神', '战歌', '听', '机', '出来', '已', '演员', '空军', '坚定', '伏笔', '明白', '感谢', '厉害', '-', '、', '黑暗', '哇', '不能', '法国', '延续', '看看', '快乐', '为了', '六分仪', '边疆', '狂喜', '史强', '马斯克', '一起', '北斗', '逃跑', '喝', '三好学生', '预警', '准备', '出现', '行为', '发现', '方块', '东西', '觉得', '跳', '浮躁', '交流', '计算机', '还行', '暗示', '夫妇', '游戏', '粮', '后面', '便秘', '拍摄', '飞', '跟', '增援', '哦', '可爱', '真是', '走', '必败', '传', '砍价', '杀人', '时候', '警告', '首长', '之', '大会', '手枪', '神游', '开', '找', '真实', '夜航', '发展', '摄影师', '搞', '三个', '上线', '带', '舰长', '戴', '失败主义', '过来', '成为', '指', '高斯', '大家', '是不是', '吃', '然后', '族', '飞船', '响', '量子', '黑', '大人', '预言家', '任务', '诶', '妻子', '正式', '万岁', '唐', '起飞', ']', 'f', '挺', '只', '死神', '学学', '信心', '确认', '以为', '鱼', '怕', '建国', '以后', '尊重', '传统', '食', '战争', '已婚', '一败涂地', '记得', '出去', 'e', '当', '而', '失败', '光学', '买', '绝', '但是', '头发', '雷达', '启动', '老师', '诞生', '密码', '响够', '时间', '喝水', '主义者', '海军', '外星人', '不用', '家', '虫子', '铁打', '哟', '做到', '/', '国家', '谢顿', '只有', '辅助', '起立', '大便', '收人', '此时', '以前', '懵', '↑', '褚岩', '弑师', '向', 'eva', '不择手段', '嘛', '该', '生', '爆头', '&', '陨石雨', '...', '成立', '[', '那么', '亚洲', '科技', '好家伙', '全宇宙', '正确', '主角', '狗头', '出', '红岸', '就要', '汉语', '地方', '前面', '事', '长', '张']

# %% [markdown]
# 将词频统计器应用到 `DataFrame` 上：

# %%
df_freq = counter_model.transform(df_rmstop)
df_freq.select("filtered", "features").show()
# Out:
# +--------------------------+--------------------+
# |                  filtered|            features|
# +--------------------------+--------------------+
# |                    [脱水]|    (500,[37],[1.0])|
# |            [技术, 公有化]|   (500,[126],[1.0])|
# |                    [脱水]|    (500,[37],[1.0])|
# |                    [浸泡]|     (500,[6],[1.0])|
# |                    [空位]|         (500,[],[])|
# |  [你, 也, 会, 空中, 劈叉]|(500,[2,24,164],[...|
# |                    [脱水]|    (500,[37],[1.0])|
# |          [让, 我, 先, 跑]|(500,[0,16,64,148...|
# |            [组织生活, 会]|   (500,[164],[1.0])|
# |              [当场, 揭穿]|         (500,[],[])|
# |                      [演]|   (500,[139],[1.0])|
# |                [对号入座]|         (500,[],[])|
# |              [狼人, 自刀]|         (500,[],[])|
# |[倍, 啥, 速, 我, 都, 一...|(500,[0,15,71,124...|
# |                    [浸泡]|     (500,[6],[1.0])|
# |              [安排, 姑娘]|         (500,[],[])|
# |              [浸泡, 浸泡]|     (500,[6],[2.0])|
# |                    [迷惑]|         (500,[],[])|
# |                      [危]|   (500,[138],[1.0])|
# |        [东方, 姑娘, 太草]|         (500,[],[])|
# +--------------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# 再用 `IDF` 对词频进行规约化：

# %%
idf = IDF(inputCol="features", outputCol="scaled_features")
idf_model = idf.fit(df_freq)
df_scaled = idf_model.transform(df_freq)
df_scaled.select("content", "scaled_features").show(n=15, truncate=50)
# Out:
# +----------------------------------+--------------------------------------------------+
# |                           content|                                   scaled_features|
# +----------------------------------+--------------------------------------------------+
# |                            脱水！|                    (500,[37],[4.366582645384245])|
# |                        技术公有化|                    (500,[126],[5.34285608186011])|
# |                              脱水|                    (500,[37],[4.366582645384245])|
# |                              浸泡|                     (500,[6],[3.591287493215301])|
# |                          空位是？|                                       (500,[],[])|
# |                    你也会空中劈叉|(500,[2,24,164],[3.0186874171988904,4.196897672...|
# |                              脱水|                    (500,[37],[4.366582645384245])|
# |                    让  我  先  跑|(500,[0,16,64,148],[2.653155019426097,3.9034518...|
# |                        组织生活会|                   (500,[164],[5.612519648809213])|
# |                          当场揭穿|                                       (500,[],[])|
# |                                演|                   (500,[139],[5.521547870603486])|
# |                       对 号 入 座|                                       (500,[],[])|
# |                          狼人自刀|                                       (500,[],[])|
# |倍啥速，我都是一段段的反复看好几遍|(500,[0,15,71,124],[2.653155019426097,3.9034518...|
# |                              浸泡|                     (500,[6],[3.591287493215301])|
# +----------------------------------+--------------------------------------------------+
# only showing top 15 rows

# %% [markdown]
# ### 模型训练

# %% [markdown]
# 我们利用得到的特征对弹幕进行 K-means 聚类：

# %%
from pyspark.ml.clustering import KMeans

kmeans = KMeans().setK(10).setSeed(123)
kmeans.setMaxIter(100)
kmeans.setFeaturesCol("scaled_features")

kmeans_model = kmeans.fit(df_scaled)
kmeans_model.setPredictionCol("cluster_labels")

df_pred = kmeans_model.transform(df_scaled)
# Out:
# 23/06/01 16:42:43 WARN InstanceBuilder$NativeBLAS: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 23/06/01 16:42:43 WARN InstanceBuilder$NativeBLAS: Failed to load implementation from:dev.ludovic.netlib.blas.ForeignLinkerBLAS
# 23/06/01 16:42:43 WARN InstanceBuilder$JavaBLAS: Failed to load implementation from:dev.ludovic.netlib.blas.VectorBLAS

# %% [markdown]
# 此时 `df_pred` 中包含了最终的聚类结果和若干中间变量：

# %%
df_pred.printSchema()
# Out:
# root
#  |-- cid: long (nullable = true)
#  |-- content: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- mode: long (nullable = true)
#  |-- post_time: long (nullable = true)
#  |-- seg: string (nullable = true)
#  |-- words: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- filtered: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- features: vector (nullable = true)
#  |-- scaled_features: vector (nullable = true)
#  |-- cluster_labels: integer (nullable = false)

# %% [markdown]
# 查看聚类结果：

# %%
df_pred.select("content", "cluster_labels").groupBy("cluster_labels").count().show()
# Out:
# +--------------+-----+
# |cluster_labels|count|
# +--------------+-----+
# |             6|  129|
# |             3|   17|
# |             5|   11|
# |             9|  187|
# |             4|   62|
# |             7|    4|
# |             2|   40|
# |             0|11047|
# |             8|    1|
# |             1|    2|
# +--------------+-----+

# %% [markdown]
# 最后将聚类结果与原始弹幕和剧集相对照：

# %%
video_info = spark.read.json("data/lec14-video-data.json", multiLine=True)
video_title = video_info.select("cid", "title")
video_title.show()
# Out:
# +---------+-------------------------------------+
# |      cid|                                title|
# +---------+-------------------------------------+
# |144541892|     【独播】我的三体之章北海传 第1集|
# |144541943|     【独播】我的三体之章北海传 第2集|
# |160377038|     【独播】我的三体之章北海传 第3集|
# |148952771|     【独播】我的三体之章北海传 第4集|
# |150894103|     【独播】我的三体之章北海传 第5集|
# |153392221|     【独播】我的三体之章北海传 第6集|
# |156629080|     【独播】我的三体之章北海传 第7集|
# |159982308|     【独播】我的三体之章北海传 第8集|
# |162395026|【独播/完结】我的三体之章北海传 第9集|
# +---------+-------------------------------------+

# %%
df_res = df_pred.select("cid", "content", "cluster_labels").filter("cluster_labels > 0")
df_res.join(video_title, df_res.cid == video_title.cid, "inner").drop(df_res.cid).\
    drop(video_title.cid).sort("cluster_labels").show(n=300)
# Out:
# +----------------------------------------+--------------+--------------------------------+
# |                                 content|cluster_labels|                           title|
# +----------------------------------------+--------------+--------------------------------+
# |                   哇————————————————...|             1|【独播】我的三体之章北海传 第4集|
# |                  老—————————航——————...|             1|【独播】我的三体之章北海传 第5集|
# |   法师凭借着在国家范围内以及国家人民...|             2|【独播】我的三体之章北海传 第5集|
# |                      智子：给我整不会了|             2|【独播】我的三体之章北海传 第3集|
# |        中国不会忘记印度尼西亚的所作所为|             2|【独播】我的三体之章北海传 第3集|
# |智子在这么近的距离帮我们拍摄，不会融化吗|             2|【独播】我的三体之章北海传 第4集|
# |            中国也不会忘记印尼的所作所为|             2|【独播】我的三体之章北海传 第3集|
# |                      办公室会不会超标了|             2|【独播】我的三体之章北海传 第3集|
# |   中国也不会忘记印度尼西亚对华人的所...|             2|【独播】我的三体之章北海传 第3集|
# |          众所周知虫子是永远不会被打败的|             2|【独播】我的三体之章北海传 第1集|
# |            中国也不会忘记印尼的所作所为|             2|【独播】我的三体之章北海传 第3集|
# |            中国也不会忘记印尼的所作所为|             2|【独播】我的三体之章北海传 第3集|
# |            了解人性到极致是不会反人类的|             2|【独播】我的三体之章北海传 第3集|
# |                      《我以为你不会跑》|             2|【独播】我的三体之章北海传 第3集|
# |        中国不会忘记印度尼西亚的所作所为|             2|【独播】我的三体之章北海传 第3集|
# |                          会不会我们的爱|             2|【独播】我的三体之章北海传 第3集|
# |                          会不会我们的爱|             2|【独播】我的三体之章北海传 第3集|
# |                    不会从袋子里飘出来吗|             2|【独播】我的三体之章北海传 第4集|
# |               吴岳:你的良心真的不会痛吗|             2|【独播】我的三体之章北海传 第3集|
# |   别说什么智子支持他，敌对文明永远不...|             2|【独播】我的三体之章北海传 第5集|
# |          程心传会很烧经费的，不会很快出|             2|【独播】我的三体之章北海传 第4集|
# |          不可能是他，他不会戴自己的像章|             2|【独播】我的三体之章北海传 第1集|
# |                      真理也不会饶了老师|             2|【独播】我的三体之章北海传 第5集|
# |                        人类不会那么团结|             2|【独播】我的三体之章北海传 第2集|
# |                                不会飘？|             2|【独播】我的三体之章北海传 第4集|
# |       就算把敌人都杀光，也不会自由的………|             2|【独播】我的三体之章北海传 第1集|
# |                  真相了，我说怎么学不会|             2|【独播】我的三体之章北海传 第2集|
# |                  三个爆头不会被怀疑嘛？|             2|【独播】我的三体之章北海传 第5集|
# |        人们平时才不会想那么多宏大叙事呢|             2|【独播】我的三体之章北海传 第2集|
# |                        人类不会那么团结|             2|【独播】我的三体之章北海传 第2集|
# |                      不会是脑子不清楚吧|             2|【独播】我的三体之章北海传 第1集|
# |   如果三体是外国作品，那逃亡会不会被...|             2|【独播】我的三体之章北海传 第2集|
# |   要是出了程心传，我应该不会看。。。...|             2|【独播】我的三体之章北海传 第2集|
# |敌人不会从海的那边打过来，他们会从天上来|             2|【独播】我的三体之章北海传 第1集|
# |        这不会是跟章北海他爸聊天的首长吧|             2|【独播】我的三体之章北海传 第5集|
# |                  脱水了也不是不会被烧。|             2|【独播】我的三体之章北海传 第4集|
# |    ←因为这里就是中国，人都是中国人，...|             2|【独播】我的三体之章北海传 第1集|
# |      动量守恒啊，他射出子弹后不会后退吗|             2|【独播】我的三体之章北海传 第5集|
# |   《凯瑟琳是爱我的，她不会也永远不可...|             2|【独播】我的三体之章北海传 第5集|
# |                我们不会谋杀你除非忍不住|             2|【独播】我的三体之章北海传 第4集|
# |                章北海会不会是为了救他！|             2|【独播】我的三体之章北海传 第3集|
# |   要是出了程心传，我应该不会看。。。...|             2|【独播】我的三体之章北海传 第2集|
# |                           智子：我*****|             3|【独播】我的三体之章北海传 第2集|
# |                  智子:#&*#&*&#&*&&#+...|             3|【独播】我的三体之章北海传 第3集|
# |                           智子：我*****|             3|【独播】我的三体之章北海传 第3集|
# |                  老航天：我**，你个大**|             3|【独播】我的三体之章北海传 第5集|
# |                            智子:我*****|             3|【独播】我的三体之章北海传 第3集|
# |                    联合国：我**********|             3|【独播】我的三体之章北海传 第3集|
# |                            智子：我****|             3|【独播】我的三体之章北海传 第3集|
# |              老航天：我********你***...|             3|【独播】我的三体之章北海传 第5集|
# |                  罗辑：****************|             3|【独播】我的三体之章北海传 第2集|
# |                              鱼：我****|             3|【独播】我的三体之章北海传 第2集|
# |                             智子：*****|             3|【独播】我的三体之章北海传 第2集|
# |                       罗辑和庄颜在*****|             3|【独播】我的三体之章北海传 第2集|
# |                         猪肉：我tm*****|             3|【独播】我的三体之章北海传 第5集|
# |                          智子：********|             3|【独播】我的三体之章北海传 第3集|
# |                           谢谢你*******|             3|【独播】我的三体之章北海传 第4集|
# |                          智子：尼玛****|             3|【独播】我的三体之章北海传 第5集|
# |                             吴岳：*****|             3|【独播】我的三体之章北海传 第3集|
# |                你的征途将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |                你的征途将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |                你的征途将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |                你的征途将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |                      星辰大海是像素画耶|             4|【独播】我的三体之章北海传 第3集|
# |              你的征途将是更广袤的大海、|             4|【独播】我的三体之章北海传 第5集|
# |              你的征途，将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |                你的征途将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |                                星辰大海|             4|【独播】我的三体之章北海传 第5集|
# |                      章北海，星辰大海。|             4|【独播】我的三体之章北海传 第3集|
# |                你的征途将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |                                星辰大海|             4|【独播】我的三体之章北海传 第1集|
# |                你的征途将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |                                星辰大海|             4|【独播】我的三体之章北海传 第3集|
# |                你的征途将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |              你的征途，将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |                你的征途将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |              你的征途，将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |                你的征途将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |                你的征途将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |                你的征途将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |                      星辰大海才是家园。|             4|【独播】我的三体之章北海传 第3集|
# |                我们的征途是星辰大海！！|             4|【独播】我的三体之章北海传 第3集|
# |              你的征途，将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |                          他试着星辰大海|             4|【独播】我的三体之章北海传 第3集|
# |                  海军的未来，是星辰大海|             4|【独播】我的三体之章北海传 第1集|
# |  张北海的手指，指的是他后面的星辰大海。|             4|【独播】我的三体之章北海传 第3集|
# |                    我们的征途是星辰大海|             4|【独播】我的三体之章北海传 第3集|
# |                                星辰大海|             4|【独播】我的三体之章北海传 第3集|
# |                            星辰大海好评|             4|【独播】我的三体之章北海传 第3集|
# |                你的征途将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |              章北海：我的目标是星辰大海|             4|【独播】我的三体之章北海传 第3集|
# |                                星辰大海|             4|【独播】我的三体之章北海传 第3集|
# |   你的征途，将是更广袤的大海你的征途...|             4|【独播】我的三体之章北海传 第5集|
# |                你的征途将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |                你的征途将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |                                星辰大海|             4|【独播】我的三体之章北海传 第5集|
# |                  你的征途是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |                                星辰大海|             4|【独播】我的三体之章北海传 第5集|
# |              你的征途是星辰大海！！！！|             4|【独播】我的三体之章北海传 第5集|
# |                你的征途将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |                                星辰大海|             4|【独播】我的三体之章北海传 第5集|
# |                你的征途将是最广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |                你的征途将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |                      你的征途是星辰大海|             4|【独播】我的三体之章北海传 第5集|
# |                    星辰大海，好浪漫啊！|             4|【独播】我的三体之章北海传 第4集|
# |                你的征途将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |                        星辰大海！！！！|             4|【独播】我的三体之章北海传 第3集|
# |                    我们的征途是星辰大海|             4|【独播】我的三体之章北海传 第1集|
# |            自然选择前进四目标星辰大海。|             4|【独播】我的三体之章北海传 第1集|
# |                我们的征途是星辰大海！！|             4|【独播】我的三体之章北海传 第3集|
# |              你的征途将是更广袤的大海！|             4|【独播】我的三体之章北海传 第5集|
# |                你的征途将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |                你的征途将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |              星辰大海才是他的归属！！！|             4|【独播】我的三体之章北海传 第3集|
# |                你的征途将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |                你的征途将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |                                星辰大海|             4|【独播】我的三体之章北海传 第3集|
# |            你的征途将是更广袤的星辰大海|             4|【独播】我的三体之章北海传 第5集|
# |                你的征途将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |          星辰大海，我的梦想是星辰大海、|             4|【独播】我的三体之章北海传 第5集|
# |                你的征途将是更广袤的大海|             4|【独播】我的三体之章北海传 第5集|
# |                                汪淼~~~~|             5|【独播】我的三体之章北海传 第4集|
# |                                 浸泡~~~|             5|【独播】我的三体之章北海传 第4集|
# |                                 浸泡~~~|             5|【独播】我的三体之章北海传 第4集|
# |                           浸~~~~泡~~~~~|             5|【独播】我的三体之章北海传 第3集|
# |            孩子们~~~~快跑~~~~~~！！！！|             5|【独播】我的三体之章北海传 第4集|
# |                     三体里的人~~~好失望|             5|【独播】我的三体之章北海传 第3集|
# |               和哈哈哈和~~~找个梦中情人|             5|【独播】我的三体之章北海传 第3集|
# |   打得过就打，打不过就跑啊。。。。多...|             5|【独播】我的三体之章北海传 第3集|
# |               礼炮2K响  钢印族解脱~~~~~|             5|【独播】我的三体之章北海传 第3集|
# |                              吴~~~岳~~~|             5|【独播】我的三体之章北海传 第3集|
# |                             再次起飞~~~|             5|【独播】我的三体之章北海传 第4集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘：时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                                时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                      时代变了哈哈哈哈哈|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                      大刘，时代变化！！|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          北海：时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                                时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                           大刘 时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                                时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                        大刘啊，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘：时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                                时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                        大刘，时代变了！|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          时代，大刘变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大人，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                           大刘 时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                        大人，时代变了。|             6|【独播】我的三体之章北海传 第2集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                        大刘，时代变了！|             6|【独播】我的三体之章北海传 第5集|
# |   时代变了。。。。当年写书的时候哪想...|             6|【独播】我的三体之章北海传 第3集|
# |    时代变了，车床都可以轻松切割陨石了！|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                                时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                        大人，是时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大人，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                           时代变了 大刘|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                                时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                                时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                                时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                            大人时代变了|             6|【独播】我的三体之章北海传 第2集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                            大宇宙时代？|             6|【独播】我的三体之章北海传 第2集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                  大刘，你看到时代变了吗|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘  时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                        大刘，时代变了。|             6|【独播】我的三体之章北海传 第5集|
# |                                时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大人，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                            大刘时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                                时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘  时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大人，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大人，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                      哈哈哈哈哈时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                        大刘啊，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大人，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                           大刘 时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                                时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大人，时代变了|             6|【独播】我的三体之章北海传 第3集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          时代变了！！！|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                                时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                           大刘,时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                            大刘时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘，时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                          大刘庄时代变了|             6|【独播】我的三体之章北海传 第5集|
# |                浸～～～～～～泡～～～～|             7|【独播】我的三体之章北海传 第3集|
# |啊～～～～呜～～～嗯～～～～～啊～～～～|             7|【独播】我的三体之章北海传 第4集|
# |                            哎～～～～～|             7|【独播】我的三体之章北海传 第1集|
# |                    浸～～～～泡～～～～|             7|【独播】我的三体之章北海传 第5集|
# |   完了完了完了完了完了，完了完了完了...|             8|【独播】我的三体之章北海传 第2集|
# |                                    脱水|             9|【独播】我的三体之章北海传 第3集|
# |                                  脱水！|             9|【独播】我的三体之章北海传 第3集|
# |                                    脱水|             9|【独播】我的三体之章北海传 第4集|
# |                                    脱水|             9|【独播】我的三体之章北海传 第3集|
# |                            中国红 敬礼!|             9|【独播】我的三体之章北海传 第1集|
# |                                    脱水|             9|【独播】我的三体之章北海传 第4集|
# |              超载超载!，超载超载'，超载|             9|【独播】我的三体之章北海传 第4集|
# |                                脱水！！|             9|【独播】我的三体之章北海传 第4集|
# |                                  脱水！|             9|【独播】我的三体之章北海传 第4集|
# |                                  脱水！|             9|【独播】我的三体之章北海传 第4集|
# |                            脱水了脱水了|             9|【独播】我的三体之章北海传 第4集|
# |                                    脱水|             9|【独播】我的三体之章北海传 第4集|
# |                             水是剧毒的!|             9|【独播】我的三体之章北海传 第4集|
# |                                    脱水|             9|【独播】我的三体之章北海传 第4集|
# |                                  脱水～|             9|【独播】我的三体之章北海传 第3集|
# |                                  快脱水|             9|【独播】我的三体之章北海传 第3集|
# |                    脱水！！！！水有剧毒|             9|【独播】我的三体之章北海传 第3集|
# |                     行了行了，十八万呢!|             9|【独播】我的三体之章北海传 第5集|
# |                                    脱水|             9|【独播】我的三体之章北海传 第5集|
# |                                    脱水|             9|【独播】我的三体之章北海传 第3集|
# |                                   脱水!|             9|【独播】我的三体之章北海传 第3集|
# |                                  脱水～|             9|【独播】我的三体之章北海传 第3集|
# |                     自然选择号,前进4!!!|             9|【独播】我的三体之章北海传 第3集|
# |                     自然选择号!前进四！|             9|【独播】我的三体之章北海传 第3集|
# |                    脱水！！！！水有剧毒|             9|【独播】我的三体之章北海传 第3集|
# |                              手断了啊!!|             9|【独播】我的三体之章北海传 第3集|
# |                                    脱水|             9|【独播】我的三体之章北海传 第5集|
# |                                    脱水|             9|【独播】我的三体之章北海传 第5集|
# |                                    脱水|             9|【独播】我的三体之章北海传 第5集|
# |                    前进!不择手段的前进!|             9|【独播】我的三体之章北海传 第5集|
# |                               这段牛逼!|             9|【独播】我的三体之章北海传 第5集|
# |                                    脱水|             9|【独播】我的三体之章北海传 第5集|
# |                                  脱水--|             9|【独播】我的三体之章北海传 第5集|
# |                                    脱水|             9|【独播】我的三体之章北海传 第5集|
# +----------------------------------------+--------------+--------------------------------+
# only showing top 300 rows
