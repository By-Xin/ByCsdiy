# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon Jan 20 10:19:16 2025

@author: doudou
"""

import nltk
from nltk.corpus import reuters
from nltk.util import ngrams
from collections import Counter, defaultdict
import random

# Step 1: Download and Load the Reuters Corpus
nltk.download('reuters')
#nltk.download('punkt')
nltk.download('punkt_tab')

# Load sentences from the Reuters Corpus
sentences = reuters.sents()
print(f"Number of sentences in Reuters Corpus: {len(sentences)}")

# Flatten sentences and tokenize into lowercase words
tokens = [word.lower() for sentence in sentences for word in sentence]

# Step 2: Generate Trigrams
trigrams = list(ngrams(tokens, 3))

# Step 3: Count Trigrams and Bigrams
trigram_counts = Counter(trigrams)
bigrams = list(ngrams(tokens, 2))
bigram_counts = Counter(bigrams)

# Step 4: Calculate Trigram Probabilities
trigram_probabilities = defaultdict(lambda: defaultdict(float))
for (w1, w2, w3), count in trigram_counts.items():
    trigram_probabilities[(w1, w2)][w3] = count / bigram_counts[(w1, w2)]

# Step 5: Generate Text Using the Trigram Model
def generate_text(trigram_probabilities, start_words, length=15):
    w1, w2 = start_words
    generated = [w1, w2]
    for _ in range(length):
        next_word_candidates = trigram_probabilities[(w1, w2)]
        if not next_word_candidates:
            break
        w3 = random.choices(
            list(next_word_candidates.keys()), 
            list(next_word_candidates.values())
        )[0]
        generated.append(w3)
        w1, w2 = w2, w3
    return ' '.join(generated)

# Example: Generate a sentence starting with "the company"
start_words = ('the', 'company')
generated_text = generate_text(trigram_probabilities, start_words,length=50)
print("Generated Text:", generated_text)

start_words = ('today', 'the')
generated_text = generate_text(trigram_probabilities, start_words)
print("Generated Text:", generated_text)


# Step 6: Compute the Probability of a Sentence
def sentence_probability(sentence, trigram_probabilities):
    tokens = nltk.word_tokenize(sentence.lower())
    trigrams = list(ngrams(tokens, 3))
    prob = 1.0
    for w1, w2, w3 in trigrams:
        prob *= trigram_probabilities[(w1, w2)].get(w3, 1e-6)  # Smoothing for unseen trigrams
    return prob

# Example: Compute the probability of a test sentence
test_sentence = "the company announced strong quarterly profits"
print("Probability of Sentence:", sentence_probability(test_sentence, trigram_probabilities))



"""
Improvements and Extensions
Smoothing:
Implement Kneser-Ney Smoothing or Laplace Smoothing for better handling of unseen trigrams.
Performance Optimization:
Use sparse matrix representations (e.g., scipy.sparse) to handle large co-occurrence matrices efficiently.
"""
# Out:
# [nltk_data] Downloading package reuters to /Users/xinby/nltk_data...
# [nltk_data] Downloading package punkt_tab to /Users/xinby/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Number of sentences in Reuters Corpus: 54716
# Generated Text: the company ' s cotton output when the dollar either way for a special meeting hayes - albion corp said the complaint seeks , among other things , payment imbalances and a two - thirds of the u . s . 10 mln dlrs charge , but the new firm , they
# Generated Text: today the increase was concentrated in textiles . under terms of the year ending in march from
# Probability of Sentence: 1.27959053103007e-21
# '\nImprovements and Extensions\nSmoothing:\nImplement Kneser-Ney Smoothing or Laplace Smoothing for better handling of unseen trigrams.\nPerformance Optimization:\nUse sparse matrix representations (e.g., scipy.sparse) to handle large co-occurrence matrices efficiently.\n'

# %%
sentences
# Out:
# [['ASIAN', 'EXPORTERS', 'FEAR', 'DAMAGE', 'FROM', 'U', '.', 'S', '.-', 'JAPAN', 'RIFT', 'Mounting', 'trade', 'friction', 'between', 'the', 'U', '.', 'S', '.', 'And', 'Japan', 'has', 'raised', 'fears', 'among', 'many', 'of', 'Asia', "'", 's', 'exporting', 'nations', 'that', 'the', 'row', 'could', 'inflict', 'far', '-', 'reaching', 'economic', 'damage', ',', 'businessmen', 'and', 'officials', 'said', '.'], ['They', 'told', 'Reuter', 'correspondents', 'in', 'Asian', 'capitals', 'a', 'U', '.', 'S', '.', 'Move', 'against', 'Japan', 'might', 'boost', 'protectionist', 'sentiment', 'in', 'the', 'U', '.', 'S', '.', 'And', 'lead', 'to', 'curbs', 'on', 'American', 'imports', 'of', 'their', 'products', '.'], ...]

# %%
trigrams
# Out:
# [('asian', 'exporters', 'fear'),
#  ('exporters', 'fear', 'damage'),
#  ('fear', 'damage', 'from'),
#  ('damage', 'from', 'u'),
#  ('from', 'u', '.'),
#  ('u', '.', 's'),
#  ('.', 's', '.-'),
#  ('s', '.-', 'japan'),
#  ('.-', 'japan', 'rift'),
#  ('japan', 'rift', 'mounting'),
#  ('rift', 'mounting', 'trade'),
#  ('mounting', 'trade', 'friction'),
#  ('trade', 'friction', 'between'),
#  ('friction', 'between', 'the'),
#  ('between', 'the', 'u'),
#  ('the', 'u', '.'),
#  ('u', '.', 's'),
#  ('.', 's', '.'),
#  ('s', '.', 'and'),
#  ('.', 'and', 'japan'),
#  ('and', 'japan', 'has'),
#  ('japan', 'has', 'raised'),
#  ('has', 'raised', 'fears'),
#  ('raised', 'fears', 'among'),
#  ('fears', 'among', 'many'),
#  ('among', 'many', 'of'),
#  ('many', 'of', 'asia'),
#  ('of', 'asia', "'"),
#  ('asia', "'", 's'),
#  ("'", 's', 'exporting'),
#  ('s', 'exporting', 'nations'),
#  ('exporting', 'nations', 'that'),
#  ('nations', 'that', 'the'),
#  ('that', 'the', 'row'),
#  ('the', 'row', 'could'),
#  ('row', 'could', 'inflict'),
#  ('could', 'inflict', 'far'),
#  ('inflict', 'far', '-'),
#  ('far', '-', 'reaching'),
#  ('-', 'reaching', 'economic'),
#  ('reaching', 'economic', 'damage'),
#  ('economic', 'damage', ','),
#  ('damage', ',', 'businessmen'),
#  (',', 'businessmen', 'and'),
#  ('businessmen', 'and', 'officials'),
#  ('and', 'officials', 'said'),
#  ('officials', 'said', '.'),
#  ('said', '.', 'they'),
#  ('.', 'they', 'told'),
#  ('they', 'told', 'reuter'),
#  ('told', 'reuter', 'correspondents'),
#  ('reuter', 'correspondents', 'in'),
#  ('correspondents', 'in', 'asian'),
#  ('in', 'asian', 'capitals'),
#  ('asian', 'capitals', 'a'),
#  ('capitals', 'a', 'u'),
#  ('a', 'u', '.'),
#  ('u', '.', 's'),
#  ('.', 's', '.'),
#  ('s', '.', 'move'),
#  ('.', 'move', 'against'),
#  ('move', 'against', 'japan'),
#  ('against', 'japan', 'might'),
#  ('japan', 'might', 'boost'),
#  ('might', 'boost', 'protectionist'),
#  ('boost', 'protectionist', 'sentiment'),
#  ('protectionist', 'sentiment', 'in'),
#  ('sentiment', 'in', 'the'),
#  ('in', 'the', 'u'),
#  ('the', 'u', '.'),
#  ('u', '.', 's'),
#  ('.', 's', '.'),
#  ('s', '.', 'and'),
#  ('.', 'and', 'lead'),
#  ('and', 'lead', 'to'),
#  ('lead', 'to', 'curbs'),
#  ('to', 'curbs', 'on'),
#  ('curbs', 'on', 'american'),
#  ('on', 'american', 'imports'),
#  ('american', 'imports', 'of'),
#  ('imports', 'of', 'their'),
#  ('of', 'their', 'products'),
#  ('their', 'products', '.'),
#  ('products', '.', 'but'),
#  ('.', 'but', 'some'),
#  ('but', 'some', 'exporters'),
#  ('some', 'exporters', 'said'),
#  ('exporters', 'said', 'that'),
#  ('said', 'that', 'while'),
#  ('that', 'while', 'the'),
#  ('while', 'the', 'conflict'),
#  ('the', 'conflict', 'would'),
#  ('conflict', 'would', 'hurt'),
#  ('would', 'hurt', 'them'),
#  ('hurt', 'them', 'in'),
#  ('them', 'in', 'the'),
#  ('in', 'the', 'long'),
#  ('the', 'long', '-'),
#  ('long', '-', 'run'),
#  ('-', 'run', ','),
#  ('run', ',', 'in'),
#  (',', 'in', 'the'),
#  ('in', 'the', 'short'),
#  ('the', 'short', '-'),
#  ('short', '-', 'term'),
#  ('-', 'term', 'tokyo'),
#  ('term', 'tokyo', "'"),
#  ('tokyo', "'", 's'),
#  ("'", 's', 'loss'),
#  ('s', 'loss', 'might'),
#  ('loss', 'might', 'be'),
#  ('might', 'be', 'their'),
#  ('be', 'their', 'gain'),
#  ('their', 'gain', '.'),
#  ('gain', '.', 'the'),
#  ('.', 'the', 'u'),
#  ('the', 'u', '.'),
#  ('u', '.', 's'),
#  ('.', 's', '.'),
#  ('s', '.', 'has'),
#  ('.', 'has', 'said'),
#  ('has', 'said', 'it'),
#  ('said', 'it', 'will'),
#  ('it', 'will', 'impose'),
#  ('will', 'impose', '300'),
#  ('impose', '300', 'mln'),
#  ('300', 'mln', 'dlrs'),
#  ('mln', 'dlrs', 'of'),
#  ('dlrs', 'of', 'tariffs'),
#  ('of', 'tariffs', 'on'),
#  ('tariffs', 'on', 'imports'),
#  ('on', 'imports', 'of'),
#  ('imports', 'of', 'japanese'),
#  ('of', 'japanese', 'electronics'),
#  ('japanese', 'electronics', 'goods'),
#  ('electronics', 'goods', 'on'),
#  ('goods', 'on', 'april'),
#  ('on', 'april', '17'),
#  ('april', '17', ','),
#  ('17', ',', 'in'),
#  (',', 'in', 'retaliation'),
#  ('in', 'retaliation', 'for'),
#  ('retaliation', 'for', 'japan'),
#  ('for', 'japan', "'"),
#  ('japan', "'", 's'),
#  ("'", 's', 'alleged'),
#  ('s', 'alleged', 'failure'),
#  ('alleged', 'failure', 'to'),
#  ('failure', 'to', 'stick'),
#  ('to', 'stick', 'to'),
#  ('stick', 'to', 'a'),
#  ('to', 'a', 'pact'),
#  ('a', 'pact', 'not'),
#  ('pact', 'not', 'to'),
#  ('not', 'to', 'sell'),
#  ('to', 'sell', 'semiconductors'),
#  ('sell', 'semiconductors', 'on'),
#  ('semiconductors', 'on', 'world'),
#  ('on', 'world', 'markets'),
#  ('world', 'markets', 'at'),
#  ('markets', 'at', 'below'),
#  ('at', 'below', 'cost'),
#  ('below', 'cost', '.'),
#  ('cost', '.', 'unofficial'),
#  ('.', 'unofficial', 'japanese'),
#  ('unofficial', 'japanese', 'estimates'),
#  ('japanese', 'estimates', 'put'),
#  ('estimates', 'put', 'the'),
#  ('put', 'the', 'impact'),
#  ('the', 'impact', 'of'),
#  ('impact', 'of', 'the'),
#  ('of', 'the', 'tariffs'),
#  ('the', 'tariffs', 'at'),
#  ('tariffs', 'at', '10'),
#  ('at', '10', 'billion'),
#  ('10', 'billion', 'dlrs'),
#  ('billion', 'dlrs', 'and'),
#  ('dlrs', 'and', 'spokesmen'),
#  ('and', 'spokesmen', 'for'),
#  ('spokesmen', 'for', 'major'),
#  ('for', 'major', 'electronics'),
#  ('major', 'electronics', 'firms'),
#  ('electronics', 'firms', 'said'),
#  ('firms', 'said', 'they'),
#  ('said', 'they', 'would'),
#  ('they', 'would', 'virtually'),
#  ('would', 'virtually', 'halt'),
#  ('virtually', 'halt', 'exports'),
#  ('halt', 'exports', 'of'),
#  ('exports', 'of', 'products'),
#  ('of', 'products', 'hit'),
#  ('products', 'hit', 'by'),
#  ('hit', 'by', 'the'),
#  ('by', 'the', 'new'),
#  ('the', 'new', 'taxes'),
#  ('new', 'taxes', '.'),
#  ('taxes', '.', '"'),
#  ('.', '"', 'we'),
#  ('"', 'we', 'wouldn'),
#  ('we', 'wouldn', "'"),
#  ('wouldn', "'", 't'),
#  ("'", 't', 'be'),
#  ('t', 'be', 'able'),
#  ('be', 'able', 'to'),
#  ('able', 'to', 'do'),
#  ('to', 'do', 'business'),
#  ('do', 'business', ',"'),
#  ('business', ',"', 'said'),
#  (',"', 'said', 'a'),
#  ('said', 'a', 'spokesman'),
#  ('a', 'spokesman', 'for'),
#  ('spokesman', 'for', 'leading'),
#  ('for', 'leading', 'japanese'),
#  ('leading', 'japanese', 'electronics'),
#  ('japanese', 'electronics', 'firm'),
#  ('electronics', 'firm', 'matsushita'),
#  ('firm', 'matsushita', 'electric'),
#  ('matsushita', 'electric', 'industrial'),
#  ('electric', 'industrial', 'co'),
#  ('industrial', 'co', 'ltd'),
#  ('co', 'ltd', '&'),
#  ('ltd', '&', 'lt'),
#  ('&', 'lt', ';'),
#  ('lt', ';', 'mc'),
#  (';', 'mc', '.'),
#  ('mc', '.', 't'),
#  ('.', 't', '>.'),
#  ('t', '>.', '"'),
#  ('>.', '"', 'if'),
#  ('"', 'if', 'the'),
#  ('if', 'the', 'tariffs'),
#  ('the', 'tariffs', 'remain'),
#  ('tariffs', 'remain', 'in'),
#  ('remain', 'in', 'place'),
#  ('in', 'place', 'for'),
#  ('place', 'for', 'any'),
#  ('for', 'any', 'length'),
#  ('any', 'length', 'of'),
#  ('length', 'of', 'time'),
#  ('of', 'time', 'beyond'),
#  ('time', 'beyond', 'a'),
#  ('beyond', 'a', 'few'),
#  ('a', 'few', 'months'),
#  ('few', 'months', 'it'),
#  ('months', 'it', 'will'),
#  ('it', 'will', 'mean'),
#  ('will', 'mean', 'the'),
#  ('mean', 'the', 'complete'),
#  ('the', 'complete', 'erosion'),
#  ('complete', 'erosion', 'of'),
#  ('erosion', 'of', 'exports'),
#  ('of', 'exports', '('),
#  ('exports', '(', 'of'),
#  ('(', 'of', 'goods'),
#  ('of', 'goods', 'subject'),
#  ('goods', 'subject', 'to'),
#  ('subject', 'to', 'tariffs'),
#  ('to', 'tariffs', ')'),
#  ('tariffs', ')', 'to'),
#  (')', 'to', 'the'),
#  ('to', 'the', 'u'),
#  ('the', 'u', '.'),
#  ('u', '.', 's'),
#  ('.', 's', '.,"'),
#  ('s', '.,"', 'said'),
#  ('.,"', 'said', 'tom'),
#  ('said', 'tom', 'murtha'),
#  ('tom', 'murtha', ','),
#  ('murtha', ',', 'a'),
#  (',', 'a', 'stock'),
#  ('a', 'stock', 'analyst'),
#  ('stock', 'analyst', 'at'),
#  ('analyst', 'at', 'the'),
#  ('at', 'the', 'tokyo'),
#  ('the', 'tokyo', 'office'),
#  ('tokyo', 'office', 'of'),
#  ('office', 'of', 'broker'),
#  ('of', 'broker', '&'),
#  ('broker', '&', 'lt'),
#  ('&', 'lt', ';'),
#  ('lt', ';', 'james'),
#  (';', 'james', 'capel'),
#  ('james', 'capel', 'and'),
#  ('capel', 'and', 'co'),
#  ('and', 'co', '>.'),
#  ('co', '>.', 'in'),
#  ('>.', 'in', 'taiwan'),
#  ('in', 'taiwan', ','),
#  ('taiwan', ',', 'businessmen'),
#  (',', 'businessmen', 'and'),
#  ('businessmen', 'and', 'officials'),
#  ('and', 'officials', 'are'),
#  ('officials', 'are', 'also'),
#  ('are', 'also', 'worried'),
#  ('also', 'worried', '.'),
#  ('worried', '.', '"'),
#  ('.', '"', 'we'),
#  ('"', 'we', 'are'),
#  ('we', 'are', 'aware'),
#  ('are', 'aware', 'of'),
#  ('aware', 'of', 'the'),
#  ('of', 'the', 'seriousness'),
#  ('the', 'seriousness', 'of'),
#  ('seriousness', 'of', 'the'),
#  ('of', 'the', 'u'),
#  ('the', 'u', '.'),
#  ('u', '.', 's'),
#  ('.', 's', '.'),
#  ('s', '.', 'threat'),
#  ('.', 'threat', 'against'),
#  ('threat', 'against', 'japan'),
#  ('against', 'japan', 'because'),
#  ('japan', 'because', 'it'),
#  ('because', 'it', 'serves'),
#  ('it', 'serves', 'as'),
#  ('serves', 'as', 'a'),
#  ('as', 'a', 'warning'),
#  ('a', 'warning', 'to'),
#  ('warning', 'to', 'us'),
#  ('to', 'us', ',"'),
#  ('us', ',"', 'said'),
#  (',"', 'said', 'a'),
#  ('said', 'a', 'senior'),
#  ('a', 'senior', 'taiwanese'),
#  ('senior', 'taiwanese', 'trade'),
#  ('taiwanese', 'trade', 'official'),
#  ('trade', 'official', 'who'),
#  ('official', 'who', 'asked'),
#  ('who', 'asked', 'not'),
#  ('asked', 'not', 'to'),
#  ('not', 'to', 'be'),
#  ('to', 'be', 'named'),
#  ('be', 'named', '.'),
#  ('named', '.', 'taiwan'),
#  ('.', 'taiwan', 'had'),
#  ('taiwan', 'had', 'a'),
#  ('had', 'a', 'trade'),
#  ('a', 'trade', 'trade'),
#  ('trade', 'trade', 'surplus'),
#  ('trade', 'surplus', 'of'),
#  ('surplus', 'of', '15'),
#  ('of', '15', '.'),
#  ('15', '.', '6'),
#  ('.', '6', 'billion'),
#  ('6', 'billion', 'dlrs'),
#  ('billion', 'dlrs', 'last'),
#  ('dlrs', 'last', 'year'),
#  ('last', 'year', ','),
#  ('year', ',', '95'),
#  (',', '95', 'pct'),
#  ('95', 'pct', 'of'),
#  ('pct', 'of', 'it'),
#  ('of', 'it', 'with'),
#  ('it', 'with', 'the'),
#  ('with', 'the', 'u'),
#  ('the', 'u', '.'),
#  ('u', '.', 's'),
#  ('.', 's', '.'),
#  ('s', '.', 'the'),
#  ('.', 'the', 'surplus'),
#  ('the', 'surplus', 'helped'),
#  ('surplus', 'helped', 'swell'),
#  ('helped', 'swell', 'taiwan'),
#  ('swell', 'taiwan', "'"),
#  ('taiwan', "'", 's'),
#  ("'", 's', 'foreign'),
#  ('s', 'foreign', 'exchange'),
#  ('foreign', 'exchange', 'reserves'),
#  ('exchange', 'reserves', 'to'),
#  ('reserves', 'to', '53'),
#  ('to', '53', 'billion'),
#  ('53', 'billion', 'dlrs'),
#  ('billion', 'dlrs', ','),
#  ('dlrs', ',', 'among'),
#  (',', 'among', 'the'),
#  ('among', 'the', 'world'),
#  ('the', 'world', "'"),
#  ('world', "'", 's'),
#  ("'", 's', 'largest'),
#  ('s', 'largest', '.'),
#  ('largest', '.', '"'),
#  ('.', '"', 'we'),
#  ('"', 'we', 'must'),
#  ('we', 'must', 'quickly'),
#  ('must', 'quickly', 'open'),
#  ('quickly', 'open', 'our'),
#  ('open', 'our', 'markets'),
#  ('our', 'markets', ','),
#  ('markets', ',', 'remove'),
#  (',', 'remove', 'trade'),
#  ('remove', 'trade', 'barriers'),
#  ('trade', 'barriers', 'and'),
#  ('barriers', 'and', 'cut'),
#  ('and', 'cut', 'import'),
#  ('cut', 'import', 'tariffs'),
#  ('import', 'tariffs', 'to'),
#  ('tariffs', 'to', 'allow'),
#  ('to', 'allow', 'imports'),
#  ('allow', 'imports', 'of'),
#  ('imports', 'of', 'u'),
#  ('of', 'u', '.'),
#  ('u', '.', 's'),
#  ('.', 's', '.'),
#  ('s', '.', 'products'),
#  ('.', 'products', ','),
#  ('products', ',', 'if'),
#  (',', 'if', 'we'),
#  ('if', 'we', 'want'),
#  ('we', 'want', 'to'),
#  ('want', 'to', 'defuse'),
#  ('to', 'defuse', 'problems'),
#  ('defuse', 'problems', 'from'),
#  ('problems', 'from', 'possible'),
#  ('from', 'possible', 'u'),
#  ('possible', 'u', '.'),
#  ('u', '.', 's'),
#  ('.', 's', '.'),
#  ('s', '.', 'retaliation'),
#  ('.', 'retaliation', ',"'),
#  ('retaliation', ',"', 'said'),
#  (',"', 'said', 'paul'),
#  ('said', 'paul', 'sheen'),
#  ('paul', 'sheen', ','),
#  ('sheen', ',', 'chairman'),
#  (',', 'chairman', 'of'),
#  ('chairman', 'of', 'textile'),
#  ('of', 'textile', 'exporters'),
#  ('textile', 'exporters', '&'),
#  ('exporters', '&', 'lt'),
#  ('&', 'lt', ';'),
#  ('lt', ';', 'taiwan'),
#  (';', 'taiwan', 'safe'),
#  ('taiwan', 'safe', 'group'),
#  ('safe', 'group', '>.'),
#  ('group', '>.', 'a'),
#  ('>.', 'a', 'senior'),
#  ('a', 'senior', 'official'),
#  ('senior', 'official', 'of'),
#  ('official', 'of', 'south'),
#  ('of', 'south', 'korea'),
#  ('south', 'korea', "'"),
#  ('korea', "'", 's'),
#  ("'", 's', 'trade'),
#  ('s', 'trade', 'promotion'),
#  ('trade', 'promotion', 'association'),
#  ('promotion', 'association', 'said'),
#  ('association', 'said', 'the'),
#  ('said', 'the', 'trade'),
#  ('the', 'trade', 'dispute'),
#  ('trade', 'dispute', 'between'),
#  ('dispute', 'between', 'the'),
#  ('between', 'the', 'u'),
#  ('the', 'u', '.'),
#  ('u', '.', 's'),
#  ('.', 's', '.'),
#  ('s', '.', 'and'),
#  ('.', 'and', 'japan'),
#  ('and', 'japan', 'might'),
#  ('japan', 'might', 'also'),
#  ('might', 'also', 'lead'),
#  ('also', 'lead', 'to'),
#  ('lead', 'to', 'pressure'),
#  ('to', 'pressure', 'on'),
#  ('pressure', 'on', 'south'),
#  ('on', 'south', 'korea'),
#  ('south', 'korea', ','),
#  ('korea', ',', 'whose'),
#  (',', 'whose', 'chief'),
#  ('whose', 'chief', 'exports'),
#  ('chief', 'exports', 'are'),
#  ('exports', 'are', 'similar'),
#  ('are', 'similar', 'to'),
#  ('similar', 'to', 'those'),
#  ('to', 'those', 'of'),
#  ('those', 'of', 'japan'),
#  ('of', 'japan', '.'),
#  ('japan', '.', 'last'),
#  ('.', 'last', 'year'),
#  ('last', 'year', 'south'),
#  ('year', 'south', 'korea'),
#  ('south', 'korea', 'had'),
#  ('korea', 'had', 'a'),
#  ('had', 'a', 'trade'),
#  ('a', 'trade', 'surplus'),
#  ('trade', 'surplus', 'of'),
#  ('surplus', 'of', '7'),
#  ('of', '7', '.'),
#  ('7', '.', '1'),
#  ('.', '1', 'billion'),
#  ('1', 'billion', 'dlrs'),
#  ('billion', 'dlrs', 'with'),
#  ('dlrs', 'with', 'the'),
#  ('with', 'the', 'u'),
#  ('the', 'u', '.'),
#  ('u', '.', 's'),
#  ('.', 's', '.,'),
#  ('s', '.,', 'up'),
#  ('.,', 'up', 'from'),
#  ('up', 'from', '4'),
#  ('from', '4', '.'),
#  ('4', '.', '9'),
#  ('.', '9', 'billion'),
#  ('9', 'billion', 'dlrs'),
#  ('billion', 'dlrs', 'in'),
#  ('dlrs', 'in', '1985'),
#  ('in', '1985', '.'),
#  ('1985', '.', 'in'),
#  ('.', 'in', 'malaysia'),
#  ('in', 'malaysia', ','),
#  ('malaysia', ',', 'trade'),
#  (',', 'trade', 'officers'),
#  ('trade', 'officers', 'and'),
#  ('officers', 'and', 'businessmen'),
#  ('and', 'businessmen', 'said'),
#  ('businessmen', 'said', 'tough'),
#  ('said', 'tough', 'curbs'),
#  ('tough', 'curbs', 'against'),
#  ('curbs', 'against', 'japan'),
#  ('against', 'japan', 'might'),
#  ('japan', 'might', 'allow'),
#  ('might', 'allow', 'hard'),
#  ('allow', 'hard', '-'),
#  ('hard', '-', 'hit'),
#  ('-', 'hit', 'producers'),
#  ('hit', 'producers', 'of'),
#  ('producers', 'of', 'semiconductors'),
#  ('of', 'semiconductors', 'in'),
#  ('semiconductors', 'in', 'third'),
#  ('in', 'third', 'countries'),
#  ('third', 'countries', 'to'),
#  ('countries', 'to', 'expand'),
#  ('to', 'expand', 'their'),
#  ('expand', 'their', 'sales'),
#  ('their', 'sales', 'to'),
#  ('sales', 'to', 'the'),
#  ('to', 'the', 'u'),
#  ('the', 'u', '.'),
#  ('u', '.', 's'),
#  ('.', 's', '.'),
#  ('s', '.', 'in'),
#  ('.', 'in', 'hong'),
#  ('in', 'hong', 'kong'),
#  ('hong', 'kong', ','),
#  ('kong', ',', 'where'),
#  (',', 'where', 'newspapers'),
#  ('where', 'newspapers', 'have'),
#  ('newspapers', 'have', 'alleged'),
#  ('have', 'alleged', 'japan'),
#  ('alleged', 'japan', 'has'),
#  ('japan', 'has', 'been'),
#  ('has', 'been', 'selling'),
#  ('been', 'selling', 'below'),
#  ('selling', 'below', '-'),
#  ('below', '-', 'cost'),
#  ('-', 'cost', 'semiconductors'),
#  ('cost', 'semiconductors', ','),
#  ('semiconductors', ',', 'some'),
#  (',', 'some', 'electronics'),
#  ('some', 'electronics', 'manufacturers'),
#  ('electronics', 'manufacturers', 'share'),
#  ('manufacturers', 'share', 'that'),
#  ('share', 'that', 'view'),
#  ('that', 'view', '.'),
#  ('view', '.', 'but'),
#  ('.', 'but', 'other'),
#  ('but', 'other', 'businessmen'),
#  ('other', 'businessmen', 'said'),
#  ('businessmen', 'said', 'such'),
#  ('said', 'such', 'a'),
#  ('such', 'a', 'short'),
#  ('a', 'short', '-'),
#  ('short', '-', 'term'),
#  ('-', 'term', 'commercial'),
#  ('term', 'commercial', 'advantage'),
#  ('commercial', 'advantage', 'would'),
#  ('advantage', 'would', 'be'),
#  ('would', 'be', 'outweighed'),
#  ('be', 'outweighed', 'by'),
#  ('outweighed', 'by', 'further'),
#  ('by', 'further', 'u'),
#  ('further', 'u', '.'),
#  ('u', '.', 's'),
#  ('.', 's', '.'),
#  ('s', '.', 'pressure'),
#  ('.', 'pressure', 'to'),
#  ('pressure', 'to', 'block'),
#  ('to', 'block', 'imports'),
#  ('block', 'imports', '.'),
#  ('imports', '.', '"'),
#  ('.', '"', 'that'),
#  ('"', 'that', 'is'),
#  ('that', 'is', 'a'),
#  ('is', 'a', 'very'),
#  ('a', 'very', 'short'),
#  ('very', 'short', '-'),
#  ('short', '-', 'term'),
#  ('-', 'term', 'view'),
#  ('term', 'view', ',"'),
#  ('view', ',"', 'said'),
#  (',"', 'said', 'lawrence'),
#  ('said', 'lawrence', 'mills'),
#  ('lawrence', 'mills', ','),
#  ('mills', ',', 'director'),
#  (',', 'director', '-'),
#  ('director', '-', 'general'),
#  ('-', 'general', 'of'),
#  ('general', 'of', 'the'),
#  ('of', 'the', 'federation'),
#  ('the', 'federation', 'of'),
#  ('federation', 'of', 'hong'),
#  ('of', 'hong', 'kong'),
#  ('hong', 'kong', 'industry'),
#  ('kong', 'industry', '.'),
#  ('industry', '.', '"'),
#  ('.', '"', 'if'),
#  ('"', 'if', 'the'),
#  ('if', 'the', 'whole'),
#  ('the', 'whole', 'purpose'),
#  ('whole', 'purpose', 'is'),
#  ('purpose', 'is', 'to'),
#  ('is', 'to', 'prevent'),
#  ('to', 'prevent', 'imports'),
#  ('prevent', 'imports', ','),
#  ('imports', ',', 'one'),
#  (',', 'one', 'day'),
#  ('one', 'day', 'it'),
#  ('day', 'it', 'will'),
#  ('it', 'will', 'be'),
#  ('will', 'be', 'extended'),
#  ('be', 'extended', 'to'),
#  ('extended', 'to', 'other'),
#  ('to', 'other', 'sources'),
#  ('other', 'sources', '.'),
#  ('sources', '.', 'much'),
#  ('.', 'much', 'more'),
#  ('much', 'more', 'serious'),
#  ('more', 'serious', 'for'),
#  ('serious', 'for', 'hong'),
#  ('for', 'hong', 'kong'),
#  ('hong', 'kong', 'is'),
#  ('kong', 'is', 'the'),
#  ('is', 'the', 'disadvantage'),
#  ('the', 'disadvantage', 'of'),
#  ('disadvantage', 'of', 'action'),
#  ('of', 'action', 'restraining'),
#  ('action', 'restraining', 'trade'),
#  ('restraining', 'trade', ',"'),
#  ('trade', ',"', 'he'),
#  (',"', 'he', 'said'),
#  ('he', 'said', '.'),
#  ('said', '.', 'the'),
#  ('.', 'the', 'u'),
#  ('the', 'u', '.'),
#  ('u', '.', 's'),
#  ('.', 's', '.'),
#  ('s', '.', 'last'),
#  ('.', 'last', 'year'),
#  ('last', 'year', 'was'),
#  ('year', 'was', 'hong'),
#  ('was', 'hong', 'kong'),
#  ('hong', 'kong', "'"),
#  ('kong', "'", 's'),
#  ("'", 's', 'biggest'),
#  ('s', 'biggest', 'export'),
#  ('biggest', 'export', 'market'),
#  ('export', 'market', ','),
#  ('market', ',', 'accounting'),
#  (',', 'accounting', 'for'),
#  ('accounting', 'for', 'over'),
#  ('for', 'over', '30'),
#  ('over', '30', 'pct'),
#  ('30', 'pct', 'of'),
#  ('pct', 'of', 'domestically'),
#  ('of', 'domestically', 'produced'),
#  ('domestically', 'produced', 'exports'),
#  ('produced', 'exports', '.'),
#  ('exports', '.', 'the'),
#  ('.', 'the', 'australian'),
#  ('the', 'australian', 'government'),
#  ('australian', 'government', 'is'),
#  ('government', 'is', 'awaiting'),
#  ('is', 'awaiting', 'the'),
#  ('awaiting', 'the', 'outcome'),
#  ('the', 'outcome', 'of'),
#  ('outcome', 'of', 'trade'),
#  ('of', 'trade', 'talks'),
#  ('trade', 'talks', 'between'),
#  ('talks', 'between', 'the'),
#  ('between', 'the', 'u'),
#  ('the', 'u', '.'),
#  ('u', '.', 's'),
#  ('.', 's', '.'),
#  ('s', '.', 'and'),
#  ('.', 'and', 'japan'),
#  ('and', 'japan', 'with'),
#  ('japan', 'with', 'interest'),
#  ('with', 'interest', 'and'),
#  ('interest', 'and', 'concern'),
#  ('and', 'concern', ','),
#  ('concern', ',', 'industry'),
#  (',', 'industry', 'minister'),
#  ('industry', 'minister', 'john'),
#  ('minister', 'john', 'button'),
#  ('john', 'button', 'said'),
#  ('button', 'said', 'in'),
#  ('said', 'in', 'canberra'),
#  ('in', 'canberra', 'last'),
#  ('canberra', 'last', 'friday'),
#  ('last', 'friday', '.'),
#  ('friday', '.', '"'),
#  ('.', '"', 'this'),
#  ('"', 'this', 'kind'),
#  ('this', 'kind', 'of'),
#  ('kind', 'of', 'deterioration'),
#  ('of', 'deterioration', 'in'),
#  ('deterioration', 'in', 'trade'),
#  ('in', 'trade', 'relations'),
#  ('trade', 'relations', 'between'),
#  ('relations', 'between', 'two'),
#  ('between', 'two', 'countries'),
#  ('two', 'countries', 'which'),
#  ('countries', 'which', 'are'),
#  ('which', 'are', 'major'),
#  ('are', 'major', 'trading'),
#  ('major', 'trading', 'partners'),
#  ('trading', 'partners', 'of'),
#  ('partners', 'of', 'ours'),
#  ('of', 'ours', 'is'),
#  ('ours', 'is', 'a'),
#  ('is', 'a', 'very'),
#  ('a', 'very', 'serious'),
#  ('very', 'serious', 'matter'),
#  ('serious', 'matter', ',"'),
#  ('matter', ',"', 'button'),
#  (',"', 'button', 'said'),
#  ('button', 'said', '.'),
#  ('said', '.', 'he'),
#  ('.', 'he', 'said'),
#  ('he', 'said', 'australia'),
#  ('said', 'australia', "'"),
#  ('australia', "'", 's'),
#  ("'", 's', 'concerns'),
#  ('s', 'concerns', 'centred'),
#  ('concerns', 'centred', 'on'),
#  ('centred', 'on', 'coal'),
#  ('on', 'coal', 'and'),
#  ('coal', 'and', 'beef'),
#  ('and', 'beef', ','),
#  ('beef', ',', 'australia'),
#  (',', 'australia', "'"),
#  ('australia', "'", 's'),
#  ("'", 's', 'two'),
#  ('s', 'two', 'largest'),
#  ('two', 'largest', 'exports'),
#  ('largest', 'exports', 'to'),
#  ('exports', 'to', 'japan'),
#  ('to', 'japan', 'and'),
#  ('japan', 'and', 'also'),
#  ('and', 'also', 'significant'),
#  ('also', 'significant', 'u'),
#  ('significant', 'u', '.'),
#  ('u', '.', 's'),
#  ('.', 's', '.'),
#  ('s', '.', 'exports'),
#  ('.', 'exports', 'to'),
#  ('exports', 'to', 'that'),
#  ('to', 'that', 'country'),
#  ('that', 'country', '.'),
#  ('country', '.', 'meanwhile'),
#  ('.', 'meanwhile', 'u'),
#  ('meanwhile', 'u', '.'),
#  ('u', '.', 's'),
#  ('.', 's', '.-'),
#  ('s', '.-', 'japanese'),
#  ('.-', 'japanese', 'diplomatic'),
#  ('japanese', 'diplomatic', 'manoeuvres'),
#  ('diplomatic', 'manoeuvres', 'to'),
#  ('manoeuvres', 'to', 'solve'),
#  ('to', 'solve', 'the'),
#  ('solve', 'the', 'trade'),
#  ('the', 'trade', 'stand'),
#  ('trade', 'stand', '-'),
#  ('stand', '-', 'off'),
#  ('-', 'off', 'continue'),
#  ('off', 'continue', '.'),
#  ('continue', '.', 'japan'),
#  ('.', 'japan', "'"),
#  ('japan', "'", 's'),
#  ("'", 's', 'ruling'),
#  ('s', 'ruling', 'liberal'),
#  ('ruling', 'liberal', 'democratic'),
#  ('liberal', 'democratic', 'party'),
#  ('democratic', 'party', 'yesterday'),
#  ('party', 'yesterday', 'outlined'),
#  ('yesterday', 'outlined', 'a'),
#  ('outlined', 'a', 'package'),
#  ('a', 'package', 'of'),
#  ('package', 'of', 'economic'),
#  ('of', 'economic', 'measures'),
#  ('economic', 'measures', 'to'),
#  ('measures', 'to', 'boost'),
#  ('to', 'boost', 'the'),
#  ('boost', 'the', 'japanese'),
#  ('the', 'japanese', 'economy'),
#  ('japanese', 'economy', '.'),
#  ('economy', '.', 'the'),
#  ('.', 'the', 'measures'),
#  ('the', 'measures', 'proposed'),
#  ('measures', 'proposed', 'include'),
#  ('proposed', 'include', 'a'),
#  ('include', 'a', 'large'),
#  ('a', 'large', 'supplementary'),
#  ('large', 'supplementary', 'budget'),
#  ('supplementary', 'budget', 'and'),
#  ('budget', 'and', 'record'),
#  ('and', 'record', 'public'),
#  ('record', 'public', 'works'),
#  ('public', 'works', 'spending'),
#  ('works', 'spending', 'in'),
#  ('spending', 'in', 'the'),
#  ('in', 'the', 'first'),
#  ('the', 'first', 'half'),
#  ('first', 'half', 'of'),
#  ('half', 'of', 'the'),
#  ('of', 'the', 'financial'),
#  ('the', 'financial', 'year'),
#  ('financial', 'year', '.'),
#  ('year', '.', 'they'),
#  ('.', 'they', 'also'),
#  ('they', 'also', 'call'),
#  ('also', 'call', 'for'),
#  ('call', 'for', 'stepped'),
#  ('for', 'stepped', '-'),
#  ('stepped', '-', 'up'),
#  ('-', 'up', 'spending'),
#  ('up', 'spending', 'as'),
#  ('spending', 'as', 'an'),
#  ('as', 'an', 'emergency'),
#  ('an', 'emergency', 'measure'),
#  ('emergency', 'measure', 'to'),
#  ('measure', 'to', 'stimulate'),
#  ('to', 'stimulate', 'the'),
#  ('stimulate', 'the', 'economy'),
#  ('the', 'economy', 'despite'),
#  ('economy', 'despite', 'prime'),
#  ('despite', 'prime', 'minister'),
#  ('prime', 'minister', 'yasuhiro'),
#  ('minister', 'yasuhiro', 'nakasone'),
#  ('yasuhiro', 'nakasone', "'"),
#  ('nakasone', "'", 's'),
#  ("'", 's', 'avowed'),
#  ('s', 'avowed', 'fiscal'),
#  ('avowed', 'fiscal', 'reform'),
#  ('fiscal', 'reform', 'program'),
#  ('reform', 'program', '.'),
#  ('program', '.', 'deputy'),
#  ('.', 'deputy', 'u'),
#  ('deputy', 'u', '.'),
#  ('u', '.', 's'),
#  ('.', 's', '.'),
#  ('s', '.', 'trade'),
#  ('.', 'trade', 'representative'),
#  ('trade', 'representative', 'michael'),
#  ('representative', 'michael', 'smith'),
#  ('michael', 'smith', 'and'),
#  ('smith', 'and', 'makoto'),
#  ('and', 'makoto', 'kuroda'),
#  ('makoto', 'kuroda', ','),
#  ('kuroda', ',', 'japan'),
#  (',', 'japan', "'"),
#  ('japan', "'", 's'),
#  ("'", 's', 'deputy'),
#  ('s', 'deputy', 'minister'),
#  ('deputy', 'minister', 'of'),
#  ('minister', 'of', 'international'),
#  ('of', 'international', 'trade'),
#  ('international', 'trade', 'and'),
#  ('trade', 'and', 'industry'),
#  ('and', 'industry', '('),
#  ('industry', '(', 'miti'),
#  ('(', 'miti', '),'),
#  ('miti', '),', 'are'),
#  ('),', 'are', 'due'),
#  ('are', 'due', 'to'),
#  ('due', 'to', 'meet'),
#  ('to', 'meet', 'in'),
#  ('meet', 'in', 'washington'),
#  ('in', 'washington', 'this'),
#  ('washington', 'this', 'week'),
#  ('this', 'week', 'in'),
#  ('week', 'in', 'an'),
#  ('in', 'an', 'effort'),
#  ('an', 'effort', 'to'),
#  ('effort', 'to', 'end'),
#  ('to', 'end', 'the'),
#  ('end', 'the', 'dispute'),
#  ('the', 'dispute', '.'),
#  ('dispute', '.', 'china'),
#  ('.', 'china', 'daily'),
#  ('china', 'daily', 'says'),
#  ('daily', 'says', 'vermin'),
#  ('says', 'vermin', 'eat'),
#  ('vermin', 'eat', '7'),
#  ('eat', '7', '-'),
#  ('7', '-', '12'),
#  ('-', '12', 'pct'),
#  ('12', 'pct', 'grain'),
#  ('pct', 'grain', 'stocks'),
#  ('grain', 'stocks', 'a'),
#  ('stocks', 'a', 'survey'),
#  ('a', 'survey', 'of'),
#  ('survey', 'of', '19'),
#  ('of', '19', 'provinces'),
#  ('19', 'provinces', 'and'),
#  ('provinces', 'and', 'seven'),
#  ('and', 'seven', 'cities'),
#  ('seven', 'cities', 'showed'),
#  ('cities', 'showed', 'vermin'),
#  ('showed', 'vermin', 'consume'),
#  ('vermin', 'consume', 'between'),
#  ('consume', 'between', 'seven'),
#  ('between', 'seven', 'and'),
#  ('seven', 'and', '12'),
#  ('and', '12', 'pct'),
#  ('12', 'pct', 'of'),
#  ('pct', 'of', 'china'),
#  ('of', 'china', "'"),
#  ('china', "'", 's'),
#  ("'", 's', 'grain'),
#  ('s', 'grain', 'stocks'),
#  ('grain', 'stocks', ','),
#  ('stocks', ',', 'the'),
#  (',', 'the', 'china'),
#  ('the', 'china', 'daily'),
#  ('china', 'daily', 'said'),
#  ('daily', 'said', '.'),
#  ('said', '.', 'it'),
#  ('.', 'it', 'also'),
#  ('it', 'also', 'said'),
#  ('also', 'said', 'that'),
#  ('said', 'that', 'each'),
#  ('that', 'each', 'year'),
#  ('each', 'year', '1'),
#  ('year', '1', '.'),
#  ('1', '.', '575'),
#  ('.', '575', 'mln'),
#  ('575', 'mln', 'tonnes'),
#  ('mln', 'tonnes', ','),
#  ('tonnes', ',', 'or'),
#  (',', 'or', '25'),
#  ('or', '25', 'pct'),
#  ('25', 'pct', ','),
#  ('pct', ',', 'of'),
#  (',', 'of', 'china'),
#  ('of', 'china', "'"),
#  ('china', "'", 's'),
#  ("'", 's', 'fruit'),
#  ('s', 'fruit', 'output'),
#  ('fruit', 'output', 'are'),
#  ('output', 'are', 'left'),
#  ('are', 'left', 'to'),
#  ('left', 'to', 'rot'),
#  ('to', 'rot', ','),
#  ('rot', ',', 'and'),
#  (',', 'and', '2'),
#  ('and', '2', '.'),
#  ('2', '.', '1'),
#  ('.', '1', 'mln'),
#  ('1', 'mln', 'tonnes'),
#  ('mln', 'tonnes', ','),
#  ('tonnes', ',', 'or'),
#  (',', 'or', 'up'),
#  ('or', 'up', 'to'),
#  ('up', 'to', '30'),
#  ('to', '30', 'pct'),
#  ('30', 'pct', ','),
#  ('pct', ',', 'of'),
#  (',', 'of', 'its'),
#  ('of', 'its', 'vegetables'),
#  ('its', 'vegetables', '.'),
#  ('vegetables', '.', 'the'),
#  ('.', 'the', 'paper'),
#  ('the', 'paper', 'blamed'),
#  ('paper', 'blamed', 'the'),
#  ('blamed', 'the', 'waste'),
#  ('the', 'waste', 'on'),
#  ('waste', 'on', 'inadequate'),
#  ('on', 'inadequate', 'storage'),
#  ('inadequate', 'storage', 'and'),
#  ('storage', 'and', 'bad'),
#  ('and', 'bad', 'preservation'),
#  ('bad', 'preservation', 'methods'),
#  ('preservation', 'methods', '.'),
#  ('methods', '.', 'it'),
#  ('.', 'it', 'said'),
#  ('it', 'said', 'the'),
#  ('said', 'the', 'government'),
#  ('the', 'government', 'had'),
#  ('government', 'had', 'launched'),
#  ('had', 'launched', 'a'),
#  ...]
